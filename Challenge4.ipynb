# %%
def isprime():
    for num in range(2,1000):
        for i in range (2,int(num/2)+1):
            if (num%i) ==0:
                print(num,"is not prime")
                break
        else:
            print(num,"is prime")
isprime()
# Out:
# 2 is prime
# 3 is prime
# 4 is not prime
# 5 is prime
# 6 is not prime
# 7 is prime
# 8 is not prime
# 9 is not prime
# 10 is not prime
# 11 is prime
# 12 is not prime
# 13 is prime
# 14 is not prime
# 15 is not prime
# 16 is not prime
# 17 is prime
# 18 is not prime
# 19 is prime
# 20 is not prime
# 21 is not prime
# 22 is not prime
# 23 is prime
# 24 is not prime
# 25 is not prime
# 26 is not prime
# 27 is not prime
# 28 is not prime
# 29 is prime
# 30 is not prime
# 31 is prime
# 32 is not prime
# 33 is not prime
# 34 is not prime
# 35 is not prime
# 36 is not prime
# 37 is prime
# 38 is not prime
# 39 is not prime
# 40 is not prime
# 41 is prime
# 42 is not prime
# 43 is prime
# 44 is not prime
# 45 is not prime
# 46 is not prime
# 47 is prime
# 48 is not prime
# 49 is not prime
# 50 is not prime
# 51 is not prime
# 52 is not prime
# 53 is prime
# 54 is not prime
# 55 is not prime
# 56 is not prime
# 57 is not prime
# 58 is not prime
# 59 is prime
# 60 is not prime
# 61 is prime
# ...

# %%
mlp=['try','to','concat','multiple','strings']
c= lambda *n: " ".join([str(x) for x in mlp])
print(c(mlp))
# Out:
# try to concat multiple strings

# %%
import math
c= lambda n:[math.sqrt(x) for x in range(100)]
print(c(100))
# Out:
# [0.0, 1.0, 1.4142135623730951, 1.7320508075688772, 2.0, 2.23606797749979, 2.449489742783178, 2.6457513110645907, 2.8284271247461903, 3.0, 3.1622776601683795, 3.3166247903554, 3.4641016151377544, 3.605551275463989, 3.7416573867739413, 3.872983346207417, 4.0, 4.123105625617661, 4.242640687119285, 4.358898943540674, 4.47213595499958, 4.58257569495584, 4.69041575982343, 4.795831523312719, 4.898979485566356, 5.0, 5.0990195135927845, 5.196152422706632, 5.291502622129181, 5.385164807134504, 5.477225575051661, 5.5677643628300215, 5.656854249492381, 5.744562646538029, 5.830951894845301, 5.916079783099616, 6.0, 6.082762530298219, 6.164414002968976, 6.244997998398398, 6.324555320336759, 6.4031242374328485, 6.48074069840786, 6.557438524302, 6.6332495807108, 6.708203932499369, 6.782329983125268, 6.855654600401044, 6.928203230275509, 7.0, 7.0710678118654755, 7.14142842854285, 7.211102550927978, 7.280109889280518, 7.3484692283495345, 7.416198487095663, 7.483314773547883, 7.54983443527075, 7.6157731
# ...

# %%
import os

def readfile(filename):
    inputfile= open(filename,"r")
    print(inputfile.read())
readfile("C:\\Users\\DELL\\Desktop\\Ineuron\\Python Challenge Dec 04, 2021.txt")
# Out:
# Todays task :
#     q1 : Try to print a prime number in between 1 to 1000
#     q2 : Try to write a function which  is equivalent  to print function in python
#     q3 : Try to write a function which is a replica of list append , extend and pop function
#     q4 : Try to write a lambda function which can return a concatination of all the string that we will pass
#     q5 : Try to write a lambda function which can return list of square of all the data between 1-100
#     q6 : Try to write a 10 Different different example of lambda function with a choice of your taks
#     q7 : Try to wwrite a funtion whihc can perform a read operation from .txt file
#
#         shivan@ineuron.ai
#         sudhashu@ineuron.ai
